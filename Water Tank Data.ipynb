# %%
import pandas as pd

# %%
df = pd.read_csv("RAWFULL_WaterTankData.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55707 entries, 0 to 55706
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BOROUGH             55707 non-null  object
#  1   ADDRESS             55707 non-null  object
#  2   ZIP                 55629 non-null  float64
#  3   TANK_NUM            55707 non-null  int64
#  4   INSPECTION_DATE     55685 non-null  object
#  5   INTERNAL_STRUCTURE  55610 non-null  object
#  6   EXTERNAL_STRUCTURE  55649 non-null  object
#  7   SEDIMENT            55605 non-null  object
#  8   BIOLOGICAL_GROWTH   55604 non-null  object
#  9   DEBRIS_INSECTS      55603 non-null  object
#  10  RODENT_BIRD         55645 non-null  object
#  11  COLIFORM            55571 non-null  object
#  12  ECOLI               55571 non-null  object
#  13  MEET_STANDARDS      11127 non-null  object
#  14  LATITUDE            55602 non-null  float64
#  15  LONGITUDE           55602 non-null  float64
#  16  COMMUNITY_BOARD     55602 non-null  float64
#  17  COUNCIL_DISTRICT    55602 non-null  float64
#  18  CENSUS_TRACT        55602 non-null  float64
# dtypes: float64(6), int64(1), object(12)
# memory usage: 8.1+ MB

# %%
## 90 tanks with biological growth
df.query("BIOLOGICAL_GROWTH == 'A'")
# Out:
#          BOROUGH               ADDRESS      ZIP  TANK_NUM INSPECTION_DATE  \
# 390    MANHATTAN     1220 Fifth Avenue  10029.0         1          5/5/21
# 593    MANHATTAN      812 Fifth Avenue  10065.0         1         4/21/15
# 605    MANHATTAN   47 East 88th Street  10128.0         1         4/20/21
# 1619   MANHATTAN   120 East End Avenue  10028.0         1         7/13/15
# 1786   MANHATTAN      125 worth street  10013.0         1        12/19/20
# ...          ...                   ...      ...       ...             ...
# 52025  MANHATTAN    160 Madison Street  10002.0         1        10/21/20
# 52464  MANHATTAN  310 East 46th Street  10017.0         1         10/7/20
# 54722  MANHATTAN  305 East 40th Street  10016.0         1         4/29/21
# 54869   BROOKLYN          760 Broadway  11206.0         1         6/12/18
# 55628  MANHATTAN        4 Sutton Place  10022.0         1        10/27/20
#
#       INTERNAL_STRUCTURE EXTERNAL_STRUCTURE SEDIMENT BIOLOGICAL_GROWTH  \
# 390                    N                  N        A                 A
# 593                    N                  N        A                 A
# 605                    N                  N        A                 A
# 1619                   N                  N        A                 A
# 1786                   A                  N        A                 A
# ...                  ...                ...      ...               ...
# 52025                  N                  N        N                 A
# 52464                  N                  N        N                 A
# 54722                  N                  N        A                 A
# 54869                  N                  N        A                 A
# 55628                  N                  N        A                 A
#
#       DEBRIS_INSECTS RODENT_BIRD COLIFORM ECOLI MEET_STANDARDS   LATITUDE  \
# 390                N           N        N     N            NaN  40.792438
# 593                A           A        N     N            NaN  40.766378
# 605                N           N        N     N            NaN  40.781980
# 1619               N           N        N     N            NaN  40.774474
# 1786               A           N        N     N            NaN  40.715428
# ...              ...         ...      ...   ...            ...        ...
# 52025              N           N        N     N            NaN  40.712488
# 52464              N           N        N     N            NaN  40.752154
# 54722              N           N        N     N            NaN  40.748469
# 54869              N           N        N     N            NaN  40.700528
# 55628              N           N        N     N            NaN  40.757512
#
#        LONGITUDE  COMMUNITY_BOARD  COUNCIL_DISTRICT  CENSUS_TRACT
# 390   -73.952448             11.0               8.0         168.0
# 593   -73.971459              8.0               4.0       11401.0
# 605   -73.957410              8.0               4.0       15002.0
# 1619  -73.945518              8.0               5.0       14401.0
# 1786  -74.002673              1.0               1.0          31.0
# ...          ...              ...               ...           ...
# 52025 -73.991924              3.0               1.0           6.0
# 52464 -73.969834              6.0               4.0          90.0
# 54722 -73.972954              6.0               4.0          88.0
# 54869 -73.941604              3.0              36.0       28501.0
# 55628 -73.960576              6.0               5.0       10601.0
#
# [90 rows x 19 columns]

# %%
## 237 tanks have unacceptable internal or external structure
df.query("(INTERNAL_STRUCTURE=='A') or (EXTERNAL_STRUCTURE=='A')")
# Out:
#          BOROUGH                     ADDRESS      ZIP  TANK_NUM  \
# 96     MANHATTAN  One One World Trade Center  10007.0         2
# 188    MANHATTAN        15 Saint james Place  10038.0         1
# 222    MANHATTAN        305 East 40th Street  10016.0         1
# 439    MANHATTAN           100 Centre street  10013.0         2
# 1161   MANHATTAN          160 Madison Street  10002.0         1
# ...          ...                         ...      ...       ...
# 55085   BROOKLYN            345 Adams street  11201.0         1
# 55117  MANHATTAN            506 Lenox Avenue  10037.0         2
# 55122   BROOKLYN            345 adams street  11201.0         3
# 55219   BROOKLYN          311 Patchen Avenue  11233.0         1
# 55359   BROOKLYN        210 Joralemon street  11201.0         1
#
#       INSPECTION_DATE INTERNAL_STRUCTURE EXTERNAL_STRUCTURE SEDIMENT  \
# 96             5/7/15                  A                  A        A
# 188            7/2/19                  N                  A        N
# 222          10/29/17                  A                  A        A
# 439          11/28/23                  N                  A        N
# 1161          3/22/19                  N                  A        N
# ...               ...                ...                ...      ...
# 55085         12/5/24                  A                  N        N
# 55117         7/28/18                  A                  A        N
# 55122        11/28/21                  A                  N        A
# 55219         9/10/19                  N                  A        N
# 55359         8/11/22                  A                  A        N
#
#       BIOLOGICAL_GROWTH DEBRIS_INSECTS RODENT_BIRD COLIFORM ECOLI  \
# 96                    N              N           N        N     N
# 188                   N              N           N        N     N
# 222                   N              N           N        N     N
# 439                   N              N           N        N     N
# 1161                  N              N           N        N     N
# ...                 ...            ...         ...      ...   ...
# 55085                 N              N           N        N     N
# 55117                 N              N           N        N     N
# 55122                 N              N           N        N     N
# 55219                 N              N           N        N     N
# 55359                 N              N           N        N     N
#
#       MEET_STANDARDS   LATITUDE  LONGITUDE  COMMUNITY_BOARD  COUNCIL_DISTRICT  \
# 96               NaN  40.713099 -74.013062              1.0               1.0
# 188              NaN  40.711571 -73.999903              3.0               1.0
# 222              NaN  40.748469 -73.972954              6.0               4.0
# 439              NaN  40.716084 -74.001425              1.0               1.0
# 1161             NaN  40.712488 -73.991924              3.0               1.0
# ...              ...        ...        ...              ...               ...
# 55085            NaN  40.693400 -73.988915              2.0              33.0
# 55117            NaN  40.814358 -73.940659             10.0               9.0
# 55122            NaN  40.693400 -73.988915              2.0              33.0
# 55219            NaN  40.680567 -73.925559              3.0              41.0
# 55359            NaN  40.692459 -73.990491              2.0              33.0
#
#        CENSUS_TRACT
# 96             13.0
# 188            25.0
# 222            88.0
# 439            29.0
# 1161            6.0
# ...             ...
# 55085          11.0
# 55117         212.0
# 55122          11.0
# 55219         381.0
# 55359           9.0
#
# [237 rows x 19 columns]

# %%
## determine that Meet Standards column is unfilled/inaccurate

df.query("MEET_STANDARDS== 'N' or MEET_STANDARDS == ' '")
# Out:
#          BOROUGH             ADDRESS      ZIP  TANK_NUM INSPECTION_DATE  \
# 2658      QUEENS       34-27 34th St  11106.0         2          1/1/21
# 15454     QUEENS       34-27 34th St  11106.0         2          1/1/21
# 19849  MANHATTAN  101 BARCLAY STREET  10007.0         1         7/28/15
# 23817      BRONX    100 Dreiser Loop  10475.0         1         2/19/23
# 24886      BRONX    100 Dreiser Loop  10475.0         1        10/31/22
# 28288  MANHATTAN    757 THIRD AVENUE  10017.0         1          5/8/15
# 40835     QUEENS       34-27 34th St  11106.0         1          1/1/21
# 42528     QUEENS       34-27 34th St  11106.0         1          1/1/21
# 43057     QUEENS       34-27 34th St  11106.0         1          1/1/21
# 46723  MANHATTAN  101 BARCLAY STREET  10007.0         2         7/28/15
# 50111     QUEENS       34-27 34th St  11106.0         2          1/1/21
#
#       INTERNAL_STRUCTURE EXTERNAL_STRUCTURE SEDIMENT BIOLOGICAL_GROWTH  \
# 2658                 NaN                NaN        N                 N
# 15454                NaN                NaN        N                 N
# 19849                  N                  N        N                 N
# 23817                  A                  A        N                 N
# 24886                  A                  A        N                 N
# 28288                  N                  N        N                 N
# 40835                  N                  N        N                 N
# 42528                NaN                NaN      NaN               NaN
# 43057                  N                NaN      NaN                 A
# 46723                  N                  N        N                 N
# 50111                NaN                NaN        N                 N
#
#       DEBRIS_INSECTS RODENT_BIRD COLIFORM ECOLI MEET_STANDARDS   LATITUDE  \
# 2658               N         NaN        N     N              N  40.758027
# 15454              N         NaN        N     N              N  40.758027
# 19849              N           N      NaN   NaN              N  40.713767
# 23817              N           N      NaN   NaN              N  40.878155
# 24886              N           N      NaN   NaN              N  40.878155
# 28288              N           N      NaN   NaN              N  40.754035
# 40835              N           A        N     A              N  40.758027
# 42528            NaN         NaN        N     A              N  40.758027
# 43057              N           A        N     A              N  40.758027
# 46723              N           N      NaN   NaN              N  40.713767
# 50111              N         NaN        N     N              N  40.758027
#
#        LONGITUDE  COMMUNITY_BOARD  COUNCIL_DISTRICT  CENSUS_TRACT
# 2658  -73.925263              1.0              26.0          57.0
# 15454 -73.925263              1.0              26.0          57.0
# 19849 -74.011925              1.0               1.0          21.0
# 23817 -73.828130             10.0              12.0       46201.0
# 24886 -73.828130             10.0              12.0       46201.0
# 28288 -73.972056              6.0               4.0          90.0
# 40835 -73.925263              1.0              26.0          57.0
# 42528 -73.925263              1.0              26.0          57.0
# 43057 -73.925263              1.0              26.0          57.0
# 46723 -74.011925              1.0               1.0          21.0
# 50111 -73.925263              1.0              26.0          57.0

# %%
df.query("(COLIFORM=='A') or (ECOLI=='A')")
# Out:
#              BOROUGH                    ADDRESS      ZIP  TANK_NUM  \
# 3610        BROOKLYN           45 Monroe Street  11238.0         1
# 3939   STATEN ISLAND             35 Hale Street  10307.0         1
# 5221       MANHATTAN          111 Centre Street  10013.0         1
# 8122   STATEN ISLAND             35 hale street  10307.0         1
# 14813  STATEN ISLAND             35 Hale Street  10307.0         1
# 15215       BROOKLYN    120 Schermerhorn Street  11201.0         1
# 15859  STATEN ISLAND             35 hale street  10307.0         1
# 17934          BRONX  1400 Pelham Parkway South  10461.0         4
# 18055       BROOKLYN        180 Montague Street  11201.0         1
# 20964       BROOKLYN      138 Willoughby Street  11201.0         1
# 33245  STATEN ISLAND             35 Hale Street  10307.0         1
# 37456  STATEN ISLAND             35 hale street  10307.0         1
# 38770      MANHATTAN           80 Centre Street  10013.0         1
# 40835         QUEENS              34-27 34th St  11106.0         1
# 42528         QUEENS              34-27 34th St  11106.0         1
# 43057         QUEENS              34-27 34th St  11106.0         1
# 44519         QUEENS            45-30 36 Street  11101.0         2
# 44612       BROOKLYN            62 HANSON PLACE  11217.0         1
# 47247       BROOKLYN        180 Montague Street  11201.0         1
# 47504          BRONX  1400 Pelham Parkway South  10461.0         3
# 49100      MANHATTAN       114 West 70th Street  10023.0         1
# 49520  STATEN ISLAND             35 hale street  10307.0         1
# 49824       BROOKLYN            62 HANSON PLACE  11217.0         1
# 50622      MANHATTAN         181 Convent Avenue  10031.0         2
# 52055      MANHATTAN          137 Centre Street  10013.0         1
#
#       INSPECTION_DATE INTERNAL_STRUCTURE EXTERNAL_STRUCTURE SEDIMENT  \
# 3610         12/14/15                  N                  N        N
# 3939          3/21/00                  N                  N        N
# 5221         12/15/15                  N                  N        N
# 8122           2/4/22                  N                  N        N
# 14813         3/21/00                  N                  N        N
# 15215        12/20/15                  N                  N        N
# 15859          2/4/22                  N                  N        N
# 17934         2/22/17                  N                  N        A
# 18055         5/12/17                  N                  N        N
# 20964         6/24/24                  N                  N        A
# 33245         3/21/00                  N                  N        N
# 37456          2/4/22                  N                  N        N
# 38770        12/16/15                  N                  N        N
# 40835          1/1/21                  N                  N        N
# 42528          1/1/21                NaN                NaN      NaN
# 43057          1/1/21                  N                NaN      NaN
# 44519         7/25/18                  N                  N        A
# 44612         8/23/23                  N                  N        N
# 47247         5/12/17                NaN                NaN      NaN
# 47504         2/22/17                  N                  N        A
# 49100        11/12/15                  N                  N        N
# 49520          2/4/22                  N                  N        N
# 49824         8/23/23                  N                  N        N
# 50622        12/27/24                  N                  N        A
# 52055        12/18/15                  N                  N        N
#
#       BIOLOGICAL_GROWTH DEBRIS_INSECTS RODENT_BIRD COLIFORM ECOLI  \
# 3610                  N              N           N        N     A
# 3939                  N              N           N        A     A
# 5221                  N              N           N        N     A
# 8122                NaN              N         NaN        A     A
# 14813                 N              N           N        A     A
# 15215                 N              N           N        N     A
# 15859               NaN              N         NaN        A     A
# 17934                 N              A           N        A     N
# 18055                 N              N           N        A     A
# 20964                 N              N           N        A     N
# 33245                 N              N           N        A     A
# 37456               NaN              N         NaN        A     A
# 38770                 N              N           N        N     A
# 40835                 N              N           A        N     A
# 42528               NaN            NaN         NaN        N     A
# 43057                 A              N           A        N     A
# 44519                 N              A           N        A     N
# 44612                 N              N           N        A     N
# 47247               NaN            NaN         NaN        A     A
# 47504                 N              A           N        A     N
# 49100                 N              N           N        A     A
# 49520               NaN              N         NaN        A     A
# 49824                 N              N           N        A     N
# 50622                 N              N           N        A     N
# 52055                 N              N           N        N     A
#
#       MEET_STANDARDS   LATITUDE  LONGITUDE  COMMUNITY_BOARD  COUNCIL_DISTRICT  \
# 3610             NaN  40.684695 -73.957367              3.0              35.0
# 3939             NaN  40.514811 -74.236572              3.0              51.0
# 5221             NaN  40.716317 -74.001277              1.0               1.0
# 8122             NaN  40.514811 -74.236572              3.0              51.0
# 14813            NaN  40.514811 -74.236572              3.0              51.0
# 15215            NaN  40.690074 -73.988923              2.0              33.0
# 15859            NaN  40.514811 -74.236572              3.0              51.0
# 17934            NaN  40.857427 -73.847079             11.0              13.0
# 18055            NaN  40.694079 -73.991756              2.0              33.0
# 20964            NaN  40.692069 -73.983135              2.0              33.0
# 33245            NaN  40.514811 -74.236572              3.0              51.0
# 37456            NaN  40.514811 -74.236572              3.0              51.0
# 38770            NaN  40.715447 -74.001890              1.0               1.0
# 40835              N  40.758027 -73.925263              1.0              26.0
# 42528              N  40.758027 -73.925263              1.0              26.0
# 43057              N  40.758027 -73.925263              1.0              26.0
# 44519            NaN  40.743509 -73.929076              2.0              26.0
# 44612            NaN  40.685414 -73.975096              2.0              35.0
# 47247            NaN  40.694079 -73.991756              2.0              33.0
# 47504            NaN  40.857427 -73.847079             11.0              13.0
# 49100            NaN  40.776318 -73.980265              7.0               6.0
# 49520            NaN  40.514811 -74.236572              3.0              51.0
# 49824            NaN  40.685414 -73.975096              2.0              35.0
# 50622            NaN  40.819574 -73.949921              9.0               9.0
# 52055            NaN  40.717157 -74.000653              1.0               1.0
#
#        CENSUS_TRACT
# 3610          229.0
# 3939          248.0
# 5221           31.0
# 8122          248.0
# 14813         248.0
# 15215          43.0
# 15859         248.0
# 17934         296.0
# 18055           9.0
# 20964          15.0
# 33245         248.0
# 37456         248.0
# 38770          29.0
# 40835          57.0
# 42528          57.0
# 43057          57.0
# 44519         179.0
# 44612          35.0
# 47247           9.0
# 47504         296.0
# 49100         153.0
# 49520         248.0
# 49824          35.0
# 50622       21703.0
# 52055          31.0

# %%
## 213 water tanks have insect debris
df.query("DEBRIS_INSECTS=='A'")
# Out:
#          BOROUGH                    ADDRESS      ZIP  TANK_NUM  \
# 593    MANHATTAN           812 Fifth Avenue  10065.0         1
# 706    MANHATTAN           462 First Avenue  10016.0         3
# 820     BROOKLYN  100 North Portland Avenue  11205.0         4
# 1550   MANHATTAN               225 Broadway  10007.0         4
# 1604       BRONX     1010 East 178th Street  10460.0         1
# ...          ...                        ...      ...       ...
# 54010  MANHATTAN          100 Centre Street  10013.0         2
# 54285  MANHATTAN          100 Centre Street  10013.0         2
# 54620     QUEENS             79-01 Broadway  11373.0         3
# 55431  MANHATTAN     40-50 Amsterdam Avenue  10023.0         1
# 55614   BROOKLYN      138 Willoughby Street  11201.0         4
#
#       INSPECTION_DATE INTERNAL_STRUCTURE EXTERNAL_STRUCTURE SEDIMENT  \
# 593           4/21/15                  N                  N        A
# 706           8/26/17                  N                  N        A
# 820            7/1/17                  N                  N        A
# 1550         12/14/15                  N                  N        N
# 1604          8/15/19                  N                  N        N
# ...               ...                ...                ...      ...
# 54010          5/6/22                  N                  A        A
# 54285          5/6/22                  N                  A        A
# 54620         11/9/15                  N                  N        A
# 55431         7/11/19                  N                  N        A
# 55614         6/20/22                  N                  N        A
#
#       BIOLOGICAL_GROWTH DEBRIS_INSECTS RODENT_BIRD COLIFORM ECOLI  \
# 593                   A              A           A        N     N
# 706                   N              A           N        N     N
# 820                   N              A           N        N     N
# 1550                  N              A           N        N     N
# 1604                  N              A           N        N     N
# ...                 ...            ...         ...      ...   ...
# 54010                 N              A           N        N     N
# 54285                 N              A           N        N     N
# 54620                 N              A           N        N     N
# 55431                 N              A           N        N     N
# 55614                 N              A           N        N     N
#
#       MEET_STANDARDS   LATITUDE  LONGITUDE  COMMUNITY_BOARD  COUNCIL_DISTRICT  \
# 593              NaN  40.766378 -73.971459              8.0               4.0
# 706              NaN  40.739497 -73.976624              6.0               4.0
# 820              NaN  40.695268 -73.976232              2.0              35.0
# 1550             NaN  40.711870 -74.008217              1.0               1.0
# 1604             NaN  40.841412 -73.880463              6.0              15.0
# ...              ...        ...        ...              ...               ...
# 54010            NaN  40.716084 -74.001425              1.0               1.0
# 54285            NaN  40.716084 -74.001425              1.0               1.0
# 54620            NaN  40.744416 -73.886097              4.0              25.0
# 55431            NaN  40.771703 -73.986685              7.0               6.0
# 55614            NaN  40.692069 -73.983135              2.0              33.0
#
#        CENSUS_TRACT
# 593         11401.0
# 706            62.0
# 820          2901.0
# 1550           21.0
# 1604          361.0
# ...             ...
# 54010          29.0
# 54285          29.0
# 54620         267.0
# 55431         151.0
# 55614          15.0
#
# [213 rows x 19 columns]

# %%
## 226 water tanks have rodent/bird, or insect debris
df.query("(RODENT_BIRD=='A') or (DEBRIS_INSECTS=='A')")
# Out:
#          BOROUGH                    ADDRESS      ZIP  TANK_NUM  \
# 593    MANHATTAN           812 Fifth Avenue  10065.0         1
# 706    MANHATTAN           462 First Avenue  10016.0         3
# 820     BROOKLYN  100 North Portland Avenue  11205.0         4
# 1550   MANHATTAN               225 Broadway  10007.0         4
# 1604       BRONX     1010 East 178th Street  10460.0         1
# ...          ...                        ...      ...       ...
# 54010  MANHATTAN          100 Centre Street  10013.0         2
# 54285  MANHATTAN          100 Centre Street  10013.0         2
# 54620     QUEENS             79-01 Broadway  11373.0         3
# 55431  MANHATTAN     40-50 Amsterdam Avenue  10023.0         1
# 55614   BROOKLYN      138 Willoughby Street  11201.0         4
#
#       INSPECTION_DATE INTERNAL_STRUCTURE EXTERNAL_STRUCTURE SEDIMENT  \
# 593           4/21/15                  N                  N        A
# 706           8/26/17                  N                  N        A
# 820            7/1/17                  N                  N        A
# 1550         12/14/15                  N                  N        N
# 1604          8/15/19                  N                  N        N
# ...               ...                ...                ...      ...
# 54010          5/6/22                  N                  A        A
# 54285          5/6/22                  N                  A        A
# 54620         11/9/15                  N                  N        A
# 55431         7/11/19                  N                  N        A
# 55614         6/20/22                  N                  N        A
#
#       BIOLOGICAL_GROWTH DEBRIS_INSECTS RODENT_BIRD COLIFORM ECOLI  \
# 593                   A              A           A        N     N
# 706                   N              A           N        N     N
# 820                   N              A           N        N     N
# 1550                  N              A           N        N     N
# 1604                  N              A           N        N     N
# ...                 ...            ...         ...      ...   ...
# 54010                 N              A           N        N     N
# 54285                 N              A           N        N     N
# 54620                 N              A           N        N     N
# 55431                 N              A           N        N     N
# 55614                 N              A           N        N     N
#
#       MEET_STANDARDS   LATITUDE  LONGITUDE  COMMUNITY_BOARD  COUNCIL_DISTRICT  \
# 593              NaN  40.766378 -73.971459              8.0               4.0
# 706              NaN  40.739497 -73.976624              6.0               4.0
# 820              NaN  40.695268 -73.976232              2.0              35.0
# 1550             NaN  40.711870 -74.008217              1.0               1.0
# 1604             NaN  40.841412 -73.880463              6.0              15.0
# ...              ...        ...        ...              ...               ...
# 54010            NaN  40.716084 -74.001425              1.0               1.0
# 54285            NaN  40.716084 -74.001425              1.0               1.0
# 54620            NaN  40.744416 -73.886097              4.0              25.0
# 55431            NaN  40.771703 -73.986685              7.0               6.0
# 55614            NaN  40.692069 -73.983135              2.0              33.0
#
#        CENSUS_TRACT
# 593         11401.0
# 706            62.0
# 820          2901.0
# 1550           21.0
# 1604          361.0
# ...             ...
# 54010          29.0
# 54285          29.0
# 54620         267.0
# 55431         151.0
# 55614          15.0
#
# [226 rows x 19 columns]

# %%
## 42 tanks have rodent or bird poop
df.query("RODENT_BIRD=='A'")
# Out:
#          BOROUGH                           ADDRESS      ZIP  TANK_NUM  \
# 593    MANHATTAN                  812 Fifth Avenue  10065.0         1
# 5113    BROOKLYN                   198 Bond Street  11217.0         1
# 7485   MANHATTAN               33 West 46th street  10036.0         1
# 7521       BRONX              1118 Grand Concourse  10456.0         1
# 7648   MANHATTAN                     1111 park ave  10128.0         1
# 9675   MANHATTAN                   720 Park Avenue  10021.0         1
# 11078   BROOKLYN              210 Joralemon Street  11201.0         2
# 11368  MANHATTAN                     1111 park ave  10128.0         2
# 13783  MANHATTAN  2971 Frederick Douglas Boulevard  10039.0         1
# 14679  MANHATTAN               15 West 56th Street  10019.0         1
# 15944   BROOKLYN              210 Joralemon Street  11201.0         3
# 17254   BROOKLYN                 426 Baltic Street  11217.0         1
# 20014  MANHATTAN                   730 Park Avenue  10021.0         1
# 20751  MANHATTAN               1879 Madison Avenue  10035.0         1
# 21384   BROOKLYN               451 Clarkson Avenue  11203.0         7
# 21711      BRONX              1118 Grand Concourse  10456.0         1
# 22144  MANHATTAN              70 East 108th Street  10029.0         2
# 24936  MANHATTAN                      520 12th Ave  10036.0         1
# 27067   BROOKLYN              210 Joralemon Street  11201.0         1
# 27669  MANHATTAN                     1111 park ave  10128.0         4
# 28296  MANHATTAN                  80 centre street  10013.0         1
# 28396   BROOKLYN             2839 West 33rd Street  11224.0         1
# 28586  MANHATTAN                160 Madison Street  10002.0         2
# 31358  MANHATTAN               12 West 96th Street  10025.0         1
# 31616  MANHATTAN                  125 worth street  10013.0         2
# 32752  MANHATTAN                80-90 Baruch Drive  10002.0         2
# 34146  MANHATTAN                   720 Park Avenue  10021.0         1
# 37397  MANHATTAN                 1901 First Avenue  10029.0         1
# 39935  MANHATTAN              201 East 80th Street  10075.0         1
# 40835     QUEENS                     34-27 34th St  11106.0         1
# 41302  MANHATTAN                31 Chambers street  10007.0         2
# 41758  MANHATTAN                31 Chambers street  10007.0         2
# 41864  MANHATTAN              70 East 108th Street  10029.0         1
# 43057     QUEENS                     34-27 34th St  11106.0         1
# 44674  MANHATTAN                   17E 48TH STREET  10017.0         1
# 45409  MANHATTAN                   38W 48TH STREET  10036.0         1
# 47494  MANHATTAN                     1111 park ave  10128.0         3
# 48033  MANHATTAN                  1405 Park Avenue  10029.0         1
# 48131   BROOKLYN                  2007 Surf Avenue  11224.0         1
# 50664      BRONX              1118 Grand Concourse  10456.0         1
# 51515  MANHATTAN                31 Chambers street  10007.0         1
# 51924   BROOKLYN             2940 West 31st Street  11224.0         1
#
#       INSPECTION_DATE INTERNAL_STRUCTURE EXTERNAL_STRUCTURE SEDIMENT  \
# 593           4/21/15                  N                  N        A
# 5113           8/6/19                  N                  A        A
# 7485          10/3/15                  A                  A        A
# 7521         11/21/21                  N                  A        A
# 7648           7/1/15                  N                  N        A
# 9675          6/23/21                  N                  N        N
# 11078        11/28/20                  A                  A        A
# 11368          7/1/15                  N                  N        A
# 13783         6/20/19                  N                  N        A
# 14679         2/11/21                  N                  N        A
# 15944        11/28/20                  A                  A        A
# 17254          8/6/19                  N                  A        A
# 20014         8/17/17                  N                  N        A
# 20751         9/19/18                  N                  N        N
# 21384         1/24/18                  N                  N        A
# 21711        11/21/20                  N                  A        A
# 22144         10/7/20                  N                  N        N
# 24936        11/22/21                  N                  A        N
# 27067        11/28/20                  A                  A        A
# 27669          7/1/15                  N                  N        A
# 28296        12/19/20                  A                  A        A
# 28396         8/14/19                  N                  N        A
# 28586        10/22/20                  N                  N        N
# 31358          8/9/17                  N                  N        A
# 31616        12/19/20                  A                  N        A
# 32752         5/21/19                  A                  N        A
# 34146         6/23/21                  N                  N        N
# 37397         1/28/16                  N                  N        N
# 39935         7/12/17                  N                  N        A
# 40835          1/1/21                  N                  N        N
# 41302        12/10/21                  A                  A        A
# 41758        11/21/20                  A                  A        A
# 41864         10/6/20                  N                  N        N
# 43057          1/1/21                  N                NaN      NaN
# 44674         7/30/15                  A                  A        A
# 45409         7/29/15                  A                  A        A
# 47494          7/1/15                  N                  N        A
# 48033          5/2/19                  N                  N        A
# 48131         6/27/19                  N                  A        N
# 50664        11/21/21                  N                  A        A
# 51515        12/10/21                  A                  A        A
# 51924         8/14/19                  N                  A        A
#
#       BIOLOGICAL_GROWTH DEBRIS_INSECTS RODENT_BIRD COLIFORM ECOLI  \
# 593                   A              A           A        N     N
# 5113                  A              A           A        N     N
# 7485                  A              A           A        N     N
# 7521                  N              A           A        N     N
# 7648                  A              A           A        N     N
# 9675                  N              N           A        N     N
# 11078                 N              A           A        N     N
# 11368                 A              A           A        N     N
# 13783                 A              A           A        N     N
# 14679                 N              A           A        N     N
# 15944                 N              A           A        N     N
# 17254                 A              A           A        N     N
# 20014                 A              A           A        N     N
# 20751                 N              N           A        N     N
# 21384                 N              N           A        N     N
# 21711                 N              A           A        N     N
# 22144                 N              N           A        N     N
# 24936                 N              N           A        N     N
# 27067                 N              A           A        N     N
# 27669                 A              A           A        N     N
# 28296                 A              A           A        N     N
# 28396                 A              A           A        N     N
# 28586                 N              N           A        N     N
# 31358                 N              N           A        N     N
# 31616                 A              A           A        N     N
# 32752                 N              A           A        N     N
# 34146                 N              N           A        N     N
# 37397                 N              N           A        N     N
# 39935                 N              A           A        N     N
# 40835                 N              N           A        N     A
# 41302                 A              A           A      NaN   NaN
# 41758                 A              A           A        N     N
# 41864                 N              N           A        N     N
# 43057                 A              N           A        N     A
# 44674                 A              A           A        N     N
# 45409                 A              A           A        N     N
# 47494                 A              A           A        N     N
# 48033                 A              A           A        N     N
# 48131                 N              N           A        N     N
# 50664                 N              A           A      NaN   NaN
# 51515                 A              A           A      NaN   NaN
# 51924                 A              A           A        N     N
#
#       MEET_STANDARDS   LATITUDE  LONGITUDE  COMMUNITY_BOARD  COUNCIL_DISTRICT  \
# 593              NaN  40.766378 -73.971459              8.0               4.0
# 5113             NaN  40.683171 -73.987413              6.0              33.0
# 7485             NaN  40.756553 -73.980242              5.0               4.0
# 7521             NaN  40.832232 -73.919655              4.0              16.0
# 7648             NaN  40.782473 -73.955513              8.0               4.0
# 9675             NaN  40.769950 -73.964681              8.0               4.0
# 11078            NaN  40.692459 -73.990491              2.0              33.0
# 11368            NaN  40.782473 -73.955513              8.0               4.0
# 13783            NaN  40.830297 -73.936456             10.0               9.0
# 14679            NaN  40.762640 -73.975258              5.0               4.0
# 15944            NaN  40.692459 -73.990491              2.0              33.0
# 17254            NaN  40.683555 -73.988552              6.0              33.0
# 20014            NaN  40.770553 -73.964897              8.0               4.0
# 20751            NaN  40.803610 -73.942250             11.0               9.0
# 21384            NaN  40.655760 -73.944602              9.0              40.0
# 21711            NaN  40.832232 -73.919655              4.0              16.0
# 22144            NaN  40.794429 -73.947434             11.0               8.0
# 24936            NaN  40.762316 -74.000036              4.0               3.0
# 27067            NaN  40.692459 -73.990491              2.0              33.0
# 27669            NaN  40.782473 -73.955513              8.0               4.0
# 28296            NaN  40.715447 -74.001890              1.0               1.0
# 28396            NaN  40.576306 -73.999849             13.0              47.0
# 28586            NaN  40.712488 -73.991924              3.0               1.0
# 31358            NaN  40.791880 -73.965222              7.0               6.0
# 31616            NaN  40.715428 -74.002673              1.0               1.0
# 32752            NaN  40.717693 -73.978081              3.0               2.0
# 34146            NaN  40.769950 -73.964681              8.0               4.0
# 37397            NaN  40.784557 -73.943780             11.0               8.0
# 39935            NaN  40.774832 -73.956454              8.0               5.0
# 40835              N  40.758027 -73.925263              1.0              26.0
# 41302            NaN  40.713402 -74.004635              1.0               1.0
# 41758            NaN  40.713402 -74.004635              1.0               1.0
# 41864            NaN  40.794429 -73.947434             11.0               8.0
# 43057              N  40.758027 -73.925263              1.0              26.0
# 44674            NaN        NaN        NaN              NaN               NaN
# 45409            NaN        NaN        NaN              NaN               NaN
# 47494            NaN  40.782473 -73.955513              8.0               4.0
# 48033            NaN  40.791797 -73.948703             11.0               8.0
# 48131            NaN  40.574792 -73.986991             13.0              47.0
# 50664            NaN  40.832232 -73.919655              4.0              16.0
# 51515            NaN  40.713402 -74.004635              1.0               1.0
# 51924            NaN  40.574480 -73.997372             13.0              47.0
#
#        CENSUS_TRACT
# 593         11401.0
# 5113           71.0
# 7485           96.0
# 7521        18102.0
# 7648        14802.0
# 9675          130.0
# 11078           9.0
# 11368       14802.0
# 13783       24302.0
# 14679       11201.0
# 15944           9.0
# 17254          71.0
# 20014         130.0
# 20751         198.0
# 21384         808.0
# 21711       18102.0
# 22144       17401.0
# 24936         129.0
# 27067           9.0
# 27669       14802.0
# 28296          29.0
# 28396         328.0
# 28586           6.0
# 31358         181.0
# 31616          31.0
# 32752        1002.0
# 34146         130.0
# 37397       15602.0
# 39935         138.0
# 40835          57.0
# 41302          31.0
# 41758          31.0
# 41864       17401.0
# 43057          57.0
# 44674           NaN
# 45409           NaN
# 47494       14802.0
# 48033         166.0
# 48131         326.0
# 50664       18102.0
# 51515          31.0
# 51924         342.0

# %%
bacteriadf.count()

# %%
dnmeet = df.query("MEET_STANDARDS == 'N'")

# %%
dnmeet.count()

# %%
df.count()

# %%
df["INSPECTION_DATE"] = pd.to_datetime(df["INSPECTION_DATE"], format="%m/%d/%Y")

# %%
start_date = pd.Timestamp("2020-01-01")
end_date = pd.Timestamp("2025-04-08")

# %%
df["INSPECTION_DATE"] = pd.to_datetime(df["INSPECTION_DATE"])

# filter the dataframe with the dates
df20tonow = df[(df["INSPECTION_DATE"] >= start_date) & (df["INSPECTION_DATE"] <= end_date)]

# %%
df20tonow.to_csv("WaterTankData_CLEANED_2020toPresent.csv", index=False)

# %%
## creating a new dataset for google map creation. using alltime data, combining rodent + insect debris violations, combining structural violations, combining coliform and ecoli violations
dfALLTIME = pd.read_csv("WaterTankData_CLEANED_ALLTIME.csv")

# %%
dirtytanksalltime = dfALLTIME.query("(RODENT_BIRD=='A') or (DEBRIS_INSECTS=='A') or (COLIFORM=='A') or (ECOLI=='A') or (BIOLOGICAL_GROWTH == 'A') or (INTERNAL_STRUCTURE=='A') or (EXTERNAL_STRUCTURE=='A')")

# %%
start_date = pd.Timestamp("2020-01-01")
end_date = pd.Timestamp("2025-04-08")
dirtytanksalltime["INSPECTION_DATE"] = pd.to_datetime(dirtytanksalltime["INSPECTION_DATE"])
dt2020tonow = dirtytanksalltime[(dirtytanksalltime["INSPECTION_DATE"] >= start_date) & (dirtytanksalltime["INSPECTION_DATE"] <= end_date)]

# %%
dt2020tonow.to_csv("Tanks_with_one_or_more_violations_2020_to_present.csv")
